# %%
import pollinations

# %%
model = pollinations.Image(model="nano_banana", width=1024, height=1024, seed=42)

# %%
img = model.Generate(prompt="superman saving a building from fire.")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x768>
