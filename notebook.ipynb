# %%
import docx2txt

# %%
with open(r"C:\Stack overflow\video_generation\Utils\video_content\scripts.docx", "r", encoding="utf-8") as f:
    script = f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open(r"C:\Stack overflow\video_generation\Utils\video_content\scripts.docx", "r", encoding="utf-8") as f:
# ----> 2     script = f.read()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x97 in position 12: invalid start byte

# %%
script = docx2txt.process(r"C:\Stack overflow\video_generation\Utils\video_content\scripts.docx")

# %%
script
# Out:
# 'Episode 1: Tummy and the Healthy Food Trouble\n\n[Scene: A bright, sunny park with birds chirping and butterflies fluttering.\n Mia sits on a picnic mat with a lunch box.]\n\nNarrator:\n\nIt was a warm, happy day, and Mia was having a picnic in the park.\nShe opened her lunch box and smiled big.\n\nInside were apple slices, banana pieces, nuts, and carrot sticks.\n\nCrunch… crunch… munch!\nMia kept eating and eating and eating.\n\nShe didn’t stop.\nShe didn’t sip water.\nShe didn’t take a break.\n\nSuddenly—\n\nMia (holding her tummy):\n\n“Owww… my tummy feels funny!”\n\nShe stood up… then sat down… then stood again.\n\n“Oh no… my tummy hurts!”\n\n✨ WHOOSH! ✨\n A swirl of rainbow sparkles filled the air—\n\nPOOF!\n Uncle Boopi appeared, riding his shiny rainbow scooter.\n\nUncle Boopi (cheerfully):\n\n“Ho-ho! Hello sunshine and smiles!\n But wait… I hear a tiny ‘owww’ sound.\n Mia, what’s wrong, little explorer?”\n\nMia:\n\n“My tummy hurts, Uncle Boopi…\n I only ate healthy food… bu
# ...
