# %%
from dotenv import load_dotenv
import os
from huggingface_hub import InferenceClient
from PIL import Image

# %%
load_dotenv()
# Out:
# True

# %%
client = InferenceClient(provider="replicate", api_key="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")

# %%
image = client.text_to_image(
    "Astronaut riding a horse",
    model="black-forest-labs/FLUX.1-dev",
)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File c:\Stack overflow\video_generation\.venv\Lib\site-packages\huggingface_hub\utils\_http.py:553, in hf_raise_for_status(response, endpoint_name)
#     552 try:
# --> 553     response.raise_for_status()
#     554 except httpx.HTTPStatusError as e:
#
# File c:\Stack overflow\video_generation\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '402 Payment Required' for url 'https://router.huggingface.co/replicate/v1/models/black-forest-labs/flux-dev/predictions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 image = client.text_to_image(
#       2     "Astronaut riding a horse",
#       3     model="black-forest-labs/FLUX.1-dev",
#       4 )
#
# File c:\Stack overflow\video_generation\.venv\Lib\site-packages\huggingface_hub\inference\_client.py:2565, in InferenceClient.text_to_image(self, prompt, negative_prompt, height, width, num_inference_steps, guidance_scale, model, scheduler, seed, extra_body)
#    2548 provider_helper = get_provider_helper(self.provider, task="text-to-image", model=model_id)
#    2549 request_parameters = provider_helper.prepare_request(
#    2550     inputs=prompt,
#    2551     parameters={
#    (...)   2563     api_key=self.token,
#    2564 )
# -> 2565 response = self._inner_post(request_parameters)
#    2566 response = provider_helper.get_response(response, request_parameters)
#    2567 return _bytes_to_image(response)
#
# File c:\Stack overflow\video_generation\.venv\Lib\site-packages\huggingface_hub\inference\_client.py:284, in InferenceClient._inner_post(self, request_parameters, stream)
#     272 try:
#     273     response = self.exit_stack.enter_context(
#     274         get_session().stream(
#     275             "POST",
#    (...)    282         )
#     283     )
# --> 284     hf_raise_for_status(response)
#     285     if stream:
#     286         return response.iter_lines()
#
# File c:\Stack overflow\video_generation\.venv\Lib\site-packages\huggingface_hub\utils\_http.py:629, in hf_raise_for_status(response, endpoint_name)
#     625     raise _format(HfHubHTTPError, message, response) from e
#     627 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     628 # as well (request id and/or server error message)
# --> 629 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: Client error '402 Payment Required' for url 'https://router.huggingface.co/replicate/v1/models/black-forest-labs/flux-dev/predictions' (Request ID: Root=1-69182293-744c149a257b3f1c36364a70;482f8532-3589-46df-b3ed-2a92e9f07ee8)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.

# %%
image.show()
